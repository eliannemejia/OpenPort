    for dim_name in reversed(dim_names):
        dim_size = len(dimensions[dim_name]['category']['index'])
        dim_idx = temp_idx % dim_size
        temp_idx = temp_idx // dim_size
        
  
        dim_keys = list(dimensions[dim_name]['category']['index'].keys())
        category_key = dim_keys[dim_idx]
        
      
        if 'label' in dimensions[dim_name]['category']:
            row[dim_name] = dimensions[dim_name]['category']['label'].get(category_key, category_key)
        else:
            row[dim_name] = category_key
    
  
    row['value'] = value
    rows.append(row)


df = pd.DataFrame(rows)
print(df.head())
print(f"\nDataFrame shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
print(f"\nValue types: {df['value'].apply(type).value_counts()}")
# Out:
#    time          geo  decision    age      sex  citizen    unit    freq  value
# 0  2024      Austria  Rejected  Total  Females  Andorra  Person  Annual      0
# 1  2024      Belgium  Rejected  Total  Females  Andorra  Person  Annual      0
# 2  2024     Bulgaria  Rejected  Total  Females  Andorra  Person  Annual      0
# 3  2024  Switzerland  Rejected  Total  Females  Andorra  Person  Annual      0
# 4  2024       Cyprus  Rejected  Total  Females  Andorra  Person  Annual      0
#
# DataFrame shape: (541728, 9)
#
# Columns: ['time', 'geo', 'decision', 'age', 'sex', 'citizen', 'unit', 'freq', 'value']
#
# Value types: value
# <class 'int'>    541728
# Name: count, dtype: int64

# %%
print("Decision types:", df['decision'].unique())
# Out:
# Decision types: ['Rejected' 'Total' 'Total positive decisions']

# %%
asylum_drop = df.drop(["unit","freq"], axis =1 )
asylum_drop.head()
# Out:
#    time          geo  decision    age      sex  citizen  value
# 0  2024      Austria  Rejected  Total  Females  Andorra      0
# 1  2024      Belgium  Rejected  Total  Females  Andorra      0
# 2  2024     Bulgaria  Rejected  Total  Females  Andorra      0
# 3  2024  Switzerland  Rejected  Total  Females  Andorra      0
# 4  2024       Cyprus  Rejected  Total  Females  Andorra      0

# %%
asylum_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541728 entries, 0 to 541727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   time      541728 non-null  object
#  1   geo       541728 non-null  object
#  2   decision  541728 non-null  object
#  3   age       541728 non-null  object
#  4   sex       541728 non-null  object
#  5   citizen   541728 non-null  object
#  6   value     541728 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 28.9+ MB

# %%
display(df)
# Out:
#         time          geo                  decision                 age  \
# 0       2024      Austria                  Rejected               Total
# 1       2024      Belgium                  Rejected               Total
# 2       2024     Bulgaria                  Rejected               Total
# 3       2024  Switzerland                  Rejected               Total
# 4       2024       Cyprus                  Rejected               Total
# ...      ...          ...                       ...                 ...
# 541723  2024     Portugal  Total positive decisions  Less than 18 years
# 541724  2024      Romania  Total positive decisions  Less than 18 years
# 541725  2024       Sweden  Total positive decisions  Less than 18 years
# 541726  2024     Slovenia  Total positive decisions  Less than 18 years
# 541727  2024     Slovakia  Total positive decisions  Less than 18 years
#
#             sex   citizen    unit    freq  value
# 0       Females   Andorra  Person  Annual      0
# 1       Females   Andorra  Person  Annual      0
# 2       Females   Andorra  Person  Annual      0
# 3       Females   Andorra  Person  Annual      0
# 4       Females   Andorra  Person  Annual      0
# ...         ...       ...     ...     ...    ...
# 541723  Unknown  Zimbabwe  Person  Annual      0
# 541724  Unknown  Zimbabwe  Person  Annual      0
# 541725  Unknown  Zimbabwe  Person  Annual      0
# 541726  Unknown  Zimbabwe  Person  Annual      0
# 541727  Unknown  Zimbabwe  Person  Annual      0
#
# [541728 rows x 9 columns]

# %%
asylum_drop = asylum_drop[asylum_drop["value"] != 0]
display(asylum_drop)
# Out:
#         time                                        geo  \
# 4004    2024  European Union - 27 countries (from 2020)
# 4796    2024  European Union - 27 countries (from 2020)
# 6336    2024                                    Austria
# 6337    2024                                    Belgium
# 6339    2024                                Switzerland
# ...      ...                                        ...
# 540895  2024                                Netherlands
# 540900  2024                                     Sweden
# 540909  2024                                    Germany
# 540914  2024  European Union - 27 countries (from 2020)
# 540919  2024                                    Ireland
#
#                         decision                 age      sex  \
# 4004                       Total               Total    Males
# 4796                       Total               Total    Total
# 6336                    Rejected               Total  Females
# 6337                    Rejected               Total  Females
# 6339                    Rejected               Total  Females
# ...                          ...                 ...      ...
# 540895                     Total  Less than 18 years    Total
# 540900                     Total  Less than 18 years    Total
# 540909  Total positive decisions  Less than 18 years    Total
# 540914  Total positive decisions  Less than 18 years    Total
# 540919  Total positive decisions  Less than 18 years    Total
#
#                      citizen  value
# 4004    United Arab Emirates      5
# 4796    United Arab Emirates      5
# 6336             Afghanistan     25
# 6337             Afghanistan     30
# 6339             Afghanistan    455
# ...                      ...    ...
# 540895              Zimbabwe      5
# 540900              Zimbabwe      5
# 540909              Zimbabwe      5
# 540914              Zimbabwe     75
# 540919              Zimbabwe     65
#
# [49277 rows x 7 columns]

# %%
asylum_drop = asylum_drop[(asylum_drop["age"] != "Total") & (asylum_drop["sex"] != "Total")]
display(asylum_drop)
# Out:
#         time                                        geo  \
# 6537    2024                                Switzerland
# 6540    2024                                    Germany
# 6543    2024                                     Greece
# 6544    2024                                      Spain
# 6545    2024  European Union - 27 countries (from 2020)
# ...      ...                                        ...
# 540084  2024                                    Germany
# 540089  2024  European Union - 27 countries (from 2020)
# 540094  2024                                    Ireland
# 540122  2024  European Union - 27 countries (from 2020)
# 540127  2024                                    Ireland
#
#                         decision                  age      sex      citizen  \
# 6537                    Rejected  From 14 to 17 years  Females  Afghanistan
# 6540                    Rejected  From 14 to 17 years  Females  Afghanistan
# 6543                    Rejected  From 14 to 17 years  Females  Afghanistan
# 6544                    Rejected  From 14 to 17 years  Females  Afghanistan
# 6545                    Rejected  From 14 to 17 years  Females  Afghanistan
# ...                          ...                  ...      ...          ...
# 540084                     Total   Less than 18 years    Males     Zimbabwe
# 540089                     Total   Less than 18 years    Males     Zimbabwe
# 540094                     Total   Less than 18 years    Males     Zimbabwe
# 540122  Total positive decisions   Less than 18 years    Males     Zimbabwe
# 540127  Total positive decisions   Less than 18 years    Males     Zimbabwe
#
#         value
# 6537       35
# 6540       40
# 6543        5
# 6544        5
# 6545       70
# ...       ...
# 540084     25
# 540089     65
# 540094     35
# 540122     35
# 540127     30
#
# [22941 rows x 7 columns]
